# %%
from mlswarm.mlswarm import function
import numpy as np
np.random.seed(42)

func_list = {}
track_history = False

# %% [markdown]
# ## 1D Functions

# %%
f = lambda x: np.take(x,0,axis=0)**2
func = function(f, "Quadratic Function")

func.init_cloud([[-1],[-0.5],[0.2],[2]])

func.minimize()

func_list[func.name] = func
#func.plot_everything(folder_name = func.name, f_dim = 1, log = True)
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.00526 (0.00000) seconds
# Cloud mean: [-0.0058983]
# Function value at cloud mean: 3.478996506782837e-05
# Function value evaluated 64 times
# Best Particle at position: [0.00044148] with function value: 1.9490326288750485e-07

# %%
f = lambda x: np.take(x,0, axis = 0)**2 - (np.cos(4 * np.pi *np.take(x,0, axis = 0)) - 1)
func = function(f, "pol_and_cosine")

func.init_cloud(np.linspace(-2,1,5)[:,np.newaxis])

func.minimize()

func_list[func.name] = func
#func.plot_everything(folder_name = func.name, f_dim = 1, log = True)
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.00776 (0.00000) seconds
# Cloud mean: [-0.00106366]
# Function value at cloud mean: 9.045920959839052e-05
# Function value evaluated 105 times
# Best Particle at position: [0.00032696] with function value: 8.54780079525181e-06

# %%
f = lambda x: np.take(x,0,axis=0)**4 - 2*(np.cos(2*np.pi*np.take(x,0,axis=0)) -1) - np.take(x,0,axis=0)**2
func = function(f, "pol_and_cosine_2")

func.init_cloud(np.linspace(-2,1.5,5)[:,np.newaxis])

func.minimize()

func_list[func.name] = func
#func.plot_everything(folder_name = func.name, f_dim = 1, log = True, limits = [-2,2])
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.00966 (0.00000) seconds
# Cloud mean: [-0.97742352]
# Function value at cloud mean: -0.02256191170518984
# Function value evaluated 135 times
# Best Particle at position: [-0.97738876] with function value: -0.02256198772302087

# %%
f = lambda x: np.sin(10*np.pi*np.take(x,0,axis=0))/(2*np.take(x,0,axis=0)) + (np.take(x,0,axis=0)-1)**4
name = "Gramacy & Lee Function" 
func = function(f, name)

func.init_cloud(np.linspace(-1,2,5)[:,np.newaxis])

func.minimize({'method': 'gradient_free',
               'algorithm': 'euler',
               'learning_rate': 0.001,
               'max_iterations': 200,
               'kernel_a': 1,
               'alpha_init': 0,
               'alpha_rate': 1,
               'gamma_init': 0,
               'track_history': True})

func_list[func.name] = func
#func.plot_everything(folder_name = func.name, f_dim = 1, log = True, limits = [-2,2])
# Out:
# Maximum amount of iterations reached
#
# The clock time (CPU time) for f_minimize was 0.01131 (0.00000) seconds
# Cloud mean: [0.42956484]
# Function value at cloud mean: 1.0381122012430641
# Function value evaluated 100 times
# Best Particle at position: [0.1462217] with function value: -2.864054561917004

# %% [markdown]
# ## 2D Functions

# %%
f = lambda x: (1.5 - np.take(x,0,axis=0) + np.take(x,0,axis=0)*np.take(x,1,axis=0))**2 + (2.25 - np.take(x,0,axis=0) + np.take(x,0,axis=0)*np.take(x,1,axis=0)**2)**2 + (2.625 - np.take(x,0,axis=0) + np.take(x,0,axis=0)*np.take(x,1,axis=0)**3)**2
func = function(f, "Beale function")

x=np.linspace(-1, 2, 5)
y=np.linspace(-1, 2, 5)
xx,yy=np.meshgrid(x,y)
coords=np.array((xx.ravel(), yy.ravel())).T
func.init_cloud(coords)

func.minimize({'var_epsilon': 0.01})

func_list[func.name] = func
#func.plot_everything(folder_name = func.name, f_dim = 2, log = True)
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.01614 (0.01562) seconds
# Cloud mean: [2.9835515  0.49843242]
# Function value at cloud mean: 0.0001900784014639704
# Function value evaluated 725 times
# Best Particle at position: [3.00534342 0.49955674] with function value: 7.672841149375674e-05

# %%
f = lambda x: -20* np.exp(-0.2*np.sqrt(0.5*(np.take(x,0,axis=0)**2 + np.take(x,1,axis=0)**2))) - np.exp(0.5*(np.cos(2*np.pi*np.take(x,0,axis=0))+np.cos(2*np.pi*np.take(x,1,axis=0)))) + np.exp(1) + 20
func = function(f,"Ackley function")

x=np.linspace(-1, 2, 3)
y=np.linspace(-1, 2, 3)
xx,yy=np.meshgrid(x,y)
coords=np.array((xx.ravel(), yy.ravel())).T
func.init_cloud(coords)

func.minimize({'var_epsilon': 0.001})

func_list[func.name] = func
#func.plot_everything(folder_name = func.name, f_dim = 2, log = True)
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.01106 (0.01562) seconds
# Cloud mean: [-0.00150344 -0.00123598]
# Function value at cloud mean: 0.005605757293551505
# Function value evaluated 162 times
# Best Particle at position: [-0.00320696 -0.00107851] with function value: 0.009874662257445266

# %%
f = lambda x: 0.5 + (np.sin(np.take(x,0,axis=0)**2 - np.take(x,1,axis=0)**2)**2 - 0.5)/(1 +0.01*(np.take(x,0,axis=0)**2 + np.take(x,1,axis=0)**2)**2)
func = function(f,"Schaffer function N. 2")

x=np.linspace(-1, 2, 3)
y=np.linspace(-1, 2, 3)
xx,yy=np.meshgrid(x,y)
coords=np.array((xx.ravel(), yy.ravel())).T
func.init_cloud(coords)

func.minimize()

func_list[func.name] = func
#func.plot_everything(folder_name = func.name, f_dim = 2, log = True)
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.01293 (0.03125) seconds
# Cloud mean: [-5.1252038e-05 -5.1252038e-05]
# Function value at cloud mean: 0.0
# Function value evaluated 252 times
# Best Particle at position: [-0.00036782 -0.00036782] with function value: 3.3306690738754696e-16

# %%
f = lambda x: np.sin(3*np.pi*x[0])**2 + (x[0] - 1)**2 * (1 + np.sin(3*np.pi*x[1])) + (x[1]-1)**2*(1+np.sin(2*np.pi*x[1])**2)
func = function(f,"Lévi function N.13")

x=np.linspace(-1, 2, 3)
y=np.linspace(-1, 2, 3)
xx,yy=np.meshgrid(x,y)
coords=np.array((xx.ravel(), yy.ravel())).T
func.init_cloud(coords)

func.minimize({'var_epsilon': 0.001})

func_list[func.name] = func
#func.plot_everything(folder_name = func.name, f_dim = 2, log = True)
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.01005 (0.00000) seconds
# Cloud mean: [0.99998145 0.98176884]
# Function value at cloud mean: 0.0003367486113457588
# Function value evaluated 252 times
# Best Particle at position: [1.00596111 1.00765009] with function value: 0.0032447493569286775

# %%
f = lambda x: -0.0001*np.power(np.abs(np.sin(x[0])*np.sin(x[1])*np.exp(np.abs(100 - np.sqrt(x[0]**2 + x[1]**2)/np.pi)))+1,0.1)
func = function(f, "Cross-in-Tray Function")

x=np.linspace(-1, 2, 3)
y=np.linspace(-1, 2, 3)
xx,yy=np.meshgrid(x,y)
coords=np.array((xx.ravel(), yy.ravel())).T
func.init_cloud(coords)

func.minimize({'var_epsilon': 0.1})

func_list[func.name] = func
#func.plot_everything(folder_name = func.name, f_dim = 2, log = True)
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.00785 (0.00000) seconds
# Cloud mean: [1.39343769 1.40968043]
# Function value at cloud mean: -2.0620106560063336
# Function value evaluated 180 times
# Best Particle at position: [1.39094497 1.4123935 ] with function value: -2.0619961569047303

# %%
f = lambda x: -(np.sin(x[0]-x[1])**2*np.sin(x[0]+x[1])**2)/(np.sqrt(x[0]**2 + x[1]**2))
func = function(f, "Keane Function")

x=np.linspace(-1, 2, 3)
y=np.linspace(-1, 2, 3)
xx,yy=np.meshgrid(x,y)
coords=np.array((xx.ravel(), yy.ravel())).T
func.init_cloud(coords)

func.minimize({'var_epsilon': 0.01})

func_list[func.name] = func
#func.plot_everything(folder_name = func.name, f_dim = 2, log = True)
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.02565 (0.03125) seconds
# Cloud mean: [-0.03135397  1.42437219]
# Function value at cloud mean: -0.6709794392552887
# Function value evaluated 558 times
# Best Particle at position: [-0.02784358  1.42289835] with function value: -0.6714064981540986

# %%
f = lambda x: -np.cos(x[0])*np.cos(x[1])*np.exp(-(x[0]-np.pi)**2 - (x[1]-np.pi)**2)
func = function(f, "Easom Function")

x=np.linspace(-2, 6, 3)
y=np.linspace(-2, 6, 3)
xx,yy=np.meshgrid(x,y)
coords=np.array((xx.ravel(), yy.ravel())).T

func.init_cloud(coords)

func.minimize({'var_epsilon': 0.01})

func_list[func.name] = func
#func.plot_everything(folder_name = func.name, f_dim = 2, log = True,limits =[0,np.pi*2,0,np.pi*2])
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.03344 (0.03125) seconds
# Cloud mean: [3.12533076 3.12533076]
# Function value at cloud mean: -0.9992069556732626
# Function value evaluated 846 times
# Best Particle at position: [3.12180576 3.12180576] with function value: -0.9988261008653214

# %% [markdown]
# # >2D Function

# %%
N_dim=2
f = lambda x: np.sum([100*(x[i+1]-x[i]**2)**2 + (1-x[i])**2 for i in range(N_dim-1)],axis=0)
func = function(f, "Rosenbrock function 3D")

#np.random.seed(42)
x=np.linspace(-1, 2, 5)
y=np.linspace(-1, 2, 5)
xx,yy=np.meshgrid(x,y)
coords=np.array((xx.ravel(), yy.ravel())).T

func.init_cloud(coords)

func.minimize({'var_epsilon': 0.01})
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.02557 (0.01562) seconds
# Cloud mean: [0.9302289  0.86680887]
# Function value at cloud mean: 0.0050879525055726885
# Function value evaluated 1575 times
# Best Particle at position: [0.9683996  0.93548067] with function value: 0.0015354861676959673

# %%
N_dim=5
f = lambda x: (np.sin(x[0])**2+ np.sin(x[1])**2 - np.exp(-x[0]**2 - x[1]**2))*np.exp(-np.sin(np.sqrt(np.abs(x[0])))**2- np.sin(np.sqrt(np.abs(x[1])))**2)
func = function(f, "Xin-She Yang N. 4 Function")

np.random.seed(42)
func.init_cloud(np.array(np.random.normal(1,2,(50,N_dim))))

func.minimize({'var_epsilon': 0.01})

func_list[func.name] = func
#func.plot_everything(folder_name = func.name, f_dim = 2, log = True)
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.06878 (0.09375) seconds
# Cloud mean: [ 4.11705669e-04 -1.49131653e-02  7.28348752e-01 -3.05380417e+00
#  -2.91546316e+00]
# Function value at cloud mean: -0.9844265113162727
# Function value evaluated 5200 times
# Best Particle at position: [-5.27002924e-04 -1.38635134e-03  7.36958915e-01 -3.06165547e+00
#  -2.93220322e+00] with function value: -0.9980848157494246

# %%
N_dim = 3
f = lambda x: np.sum([(x[i]**2 - i)**2 for i in range(N_dim)],axis=0)
func = function(f, "Qing Function")

func.init_cloud(np.array(np.random.normal(0,3,(20, N_dim))))

func.minimize({'var_epsilon': 0.0001,
               'kernel_a':1,
               'alpha_rate': 1})

func_list[func.name] = func
#func.plot_everything(folder_name = func.name, f_dim = 10, log = True,limits =[-3,3,-3,3])
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.02476 (0.03125) seconds
# Cloud mean: [-0.1114973  -1.00247275 -1.41463918]
# Function value at cloud mean: 0.0001805140850242839
# Function value evaluated 940 times
# Best Particle at position: [-0.11312877 -1.00347566 -1.41421455] with function value: 0.00021228088872456537

# %% [markdown]
# ## Summarizing Data

# %%
import pandas as pd

# %%
data_matrix = []
for func_name, func in func_list.items():
    header, parameters = func.get_all_parameters(False, "")
    data_matrix.append(parameters)

df = pd.DataFrame(data_matrix, columns = header)
df.to_csv("Images/Benchmarking Data 2.csv", sep=',',index=False)
df
# Out:
#                           name    N     cloud_var  \
# 0           Quadratic Function   50  1.658081e-07
# 1               pol_and_cosine   50  7.359497e-06
# 2             pol_and_cosine_2   50  9.801237e-05
# 3       Gramacy & Lee Function   50  9.760667e-05
# 4               Beale function   50  8.478475e-05
# 5              Ackley function  100  9.695734e-05
# 6       Schaffer function N. 2   20  8.726278e-06
# 7           Lévi function N.13   50  3.093885e-07
# 8       Cross-in-Tray Function   50  9.241681e-05
# 9               Keane Function   50  5.401354e-05
# 10              Easom Function  100  9.983683e-05
# 11  Xin-She Yang N. 4 Function  200  9.907905e-05
# 12               Qing Function  100  9.989183e-05
#
#                                            cloud_mean  \
# 0                                           [0.00032]
# 1                                          [-0.00023]
# 2                                          [-0.00076]
# 3                                           [0.34835]
# 4                                   [3.36211 0.57196]
# 5                                 [ 0.00081 -0.00251]
# 6                                 [ 0.05347 -0.07169]
# 7                                   [0.99983 1.00729]
# 8                                   [1.90686 1.95393]
# 9                                   [1.20485 1.24181]
# 10                                  [3.14162 3.14162]
# 11                                [-0.00015  0.00044]
# 12  [-0.32361 -1.01493  1.42102  1.7348  -1.99932 ...
#
#             cloud_mean_func     train_method  elapsed_iterations  \
# 0    1.0020994083109638e-07  swarm_derivfree                 513
# 1       4.0559315413607e-06  swarm_derivfree                 197
# 2    2.2368496326708912e-05  swarm_derivfree                 190
# 3   -1.2530830798738781e+00  swarm_derivfree                 210
# 4     1.552811082762947e-02  swarm_derivfree                 242
# 5    7.6566803337279055e-03  swarm_derivfree                 774
# 6     5.521334954294854e-06  swarm_derivfree                 830
# 7     5.588786125644021e-05  swarm_derivfree                 226
# 8   -1.9926637905165787e+00  swarm_derivfree                2921
# 9    -3.235907253742199e-04  swarm_derivfree                 283
# 10   -9.999999982885365e-01  swarm_derivfree                1098
# 11   -9.994097553632695e-01  swarm_derivfree                1045
# 12   1.2802188105064642e-02  swarm_derivfree                2209
#
#     function_evaluations  clock_time  cpu_time  max_iterations  var_epsilon  \
# 0                  25650    0.109020  0.109375           10000      0.00010
# 1                   9850    0.047429  0.046875            5000      0.00001
# 2                   9500    0.057316  0.062500           10000      0.00010
# 3                  10500    0.043438  0.046875          100000      0.00010
# 4                  12100    0.055224  0.046875           10000      0.00010
# 5                  77400    0.277145  0.296875          100000      0.00010
# 6                  16600    0.152260  0.156250          100000      0.00001
# 7                  11300    0.063161  0.078125          100000      0.00001
# 8                 146050    0.653050  0.656250          100000      0.00010
# 9                  14150    0.066891  0.062500          100000      0.00010
# 10                109800    0.363217  0.359375           10000      0.00010
# 11                209000    1.439598  1.437500          100000      0.00010
# 12                220900    2.739321  2.734375          100000      0.00010
#
#     learning_rate  kernel_a  alpha_init  alpha_rate  beta  gamma  gamma_rate
# 0           0.010    0.0010           0           1     0     10           0
# 1           0.010    0.0010           0          10     0      1           0
# 2           0.010    0.0010           0          10     0      1           0
# 3           0.001    0.0100           0          10     0      1           0
# 4           0.001    0.1000           0           1     0      1           0
# 5           0.010    0.0010           0           1     0      1           0
# 6           0.010    0.0010           0           1     0      1           0
# 7           0.010    0.0100           0           1     0      1           0
# 8           0.010    0.1000           0           1     0      1           0
# 9           0.010    0.0100           0           1     0      1           0
# 10          0.010    0.0010           0           1     0      1           0
# 11          0.010    0.0010           0           1     0      1           0
# 12          0.010    0.0001           0          10     0      1           0
