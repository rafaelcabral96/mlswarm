# %%
from mlswarm.mlswarm import function
import numpy as np
np.random.seed(42)

func_list = {}
track_history = False

# %% [markdown]
# ## 1D Functions

# %%
f = lambda x: x[0]**2
name = "Quadratic Function"
func = function(f, name)

np.random.seed(42)
func.init_cloud(False, True, [-5,5], 50, function_dim = 3)

func.minimize(max_iterations = 1000, var_epsilon = 0, 
              learning_rate = 0.01,
              method = "swarm_derivfree", N_sample = False,
              kernel_a = 1, alpha_init = 0, alpha_rate = 1, beta=0, gamma_init=1, gamma_rate = 0,
              verbose = False, track_history = True)

func.cloud_var
#func_list[func.name] = func
#func.plot_everything(folder_name = func.name, f_dim = 1, log = True)
# Out:
# Maximum amount of iterations reached
#
# Function value at cloud mean: 0.00030745584434738676
# Function value evaluated 50000 times
#
# The clock time (CPU time) for train_fmin was 1.35569 (1.35938) seconds
# 0.0005281728597420042

# %%
f = lambda x: x[0]**2 - (np.cos(4 * np.pi *x[0]) - 1)
name = "pol_and_cosine"
func = function(f, name)

np.random.seed(42)
func.init_cloud(np.array(np.random.normal(3,1,(1,50))))

func.minimize(max_iterations = 5000, var_epsilon = 0.00001, 
              learning_rate = 0.01,
              method = "swarm_derivfree", N_sample = False,
              kernel_a = 0.01, alpha_init = 0, alpha_rate = 10, beta=0, gamma_init=1, gamma_rate = 0,
              verbose = False, track_history = True)

func_list[func.name] = func
func.plot_everything(folder_name = func.name, f_dim = 1, log = True)
# Out:
# Maximum amount of iterations reached
#
# Function value at cloud mean: 5.564098021283885e-05
# Function value evaluated 250000 times
#
# The clock time (CPU time) for train_fmin was 10.42529 (10.42188) seconds

# %%
f = lambda x: x[0]**4 - 2*(np.cos(2*np.pi*x[0]) -1) - x[0]**2
name = "pol_and_cosine_2"
func = function(f, name)

np.random.seed(42)
func.init_cloud(np.array(np.random.normal(3,1,(1,50))))

func.minimize(max_iterations = 10000, var_epsilon = 0.0001, 
              learning_rate = 0.01,
              method = "swarm_derivfree",
              kernel_a = 0.001, alpha_init = 0, alpha_rate = 10, beta=0, gamma=1,
              verbose = False, track_history = track_history)

func_list[func.name] = func
#func.plot_everything(folder_name = func.name, f_dim = 1, log = True, limits = [-2,2])
# Out:
# Convergence achieved - Particles are localized
#
# Function value at cloud mean: 2.1112577040249385e-05
# Function value evaluated 353250 times
#
# The clock time (CPU time) for train_fmin was 1.22211 (1.21875) seconds

# %%
f = lambda x: np.sin(10*np.pi*x[0])/(2*x[0]) + (x[0]-1)**4
name = "Gramacy & Lee Function" 
func = function(f, name)

np.random.seed(42)
func.init_cloud(np.array(np.random.normal(-3,1,(1,50))))

func.minimize(max_iterations = 100000, var_epsilon = 0.0001, 
              learning_rate = 0.001,
              method = "swarm_derivfree",
              kernel_a = 0.01, alpha_init = 0, alpha_rate = 10, beta=0, gamma=10,
              verbose = False, track_history = track_history)

func_list[func.name] = func
#func.plot_everything(folder_name = func.name, f_dim = 1, log = True, limits = [-2,2])
# Out:
# Convergence achieved - Particles are localized
#
# Function value at cloud mean: -0.8689942603533318
# Function value evaluated 351100 times
#
# The clock time (CPU time) for train_fmin was 1.19681 (1.20312) seconds

# %% [markdown]
# ## 2D Functions

# %%
f = lambda x: (1.5 - x[0] + x[0]*x[1])**2 + (2.25 - x[0] + x[0]*x[1]**2)**2 + (2.625 - x[0] + x[0]*x[1]**3)**2
name = "Beale function"
func = function(f, name)

np.random.seed(42)
func.init_cloud(np.array(np.random.normal(-2,1,(2,50))))

func.minimize(max_iterations = 10000, var_epsilon = 0.00001, 
              learning_rate = 0.001,
              method = "swarm_derivfree",
              kernel_a = 1, alpha_init = 0, alpha_rate = 5, beta=0, gamma=1,
              verbose = False, track_history = track_history)

func_list[func.name] = func
#func.plot_everything(folder_name = func.name, f_dim = 2, log = True)
# Out:
# Convergence achieved - Particles are localized
#
# Function value at cloud mean: 0.0025352705940708186
# Function value evaluated 157250 times
#
# The clock time (CPU time) for train_fmin was 0.59548 (0.59375) seconds

# %%
f = lambda x: -20* np.exp(-0.2*np.sqrt(0.5*(x[0]**2 + x[1]**2))) - np.exp(0.5*(np.cos(2*np.pi*x[0])+np.cos(2*np.pi*x[1]))) + np.exp(1) + 20
name = "Ackley function"
func = function(f,name)

np.random.seed(42)
func.init_cloud(np.array(np.random.normal(3,1,(2,100))))

func.minimize(max_iterations = 100000, var_epsilon = 0.0001, 
              learning_rate = 0.01,
              method = "swarm_derivfree",
              kernel_a = 0.001, alpha_init = 0, alpha_rate = 1, beta=0, gamma=1,
              verbose = False, track_history = track_history)

func_list[func.name] = func
#func.plot_everything(folder_name = func.name, f_dim = 2, log = True)
# Out:
# Convergence achieved - Particles are localized
#
# Function value at cloud mean: 0.04003751734757799
# Function value evaluated 2222900 times
#
# The clock time (CPU time) for train_fmin was 6.74912 (6.67188) seconds

# %%
f = lambda x: 0.5 + (np.sin(x[0]**2 - x[1]**2)**2 - 0.5)/(1 +0.01*(x[0]**2 + x[1]**2)**2)
name = "Schaffer function N. 2"
func = function(f,name)

np.random.seed(42)
func.init_cloud(np.array(np.random.normal(0,1,(2,20))))

func.minimize(max_iterations = 100000, var_epsilon = 0.00001, 
              learning_rate = 0.01,
              method = "swarm_derivfree",
              kernel_a = 0.01, alpha_init = 0, alpha_rate = 1, beta=0, gamma=1,
              verbose = False, track_history = track_history)

func_list[func.name] = func
#func.plot_everything(folder_name = func.name, f_dim = 2, log = True)
# Out:
# Convergence achieved - Particles are localized
#
# Function value at cloud mean: 4.6377777507267126e-08
# Function value evaluated 447200 times
#
# The clock time (CPU time) for train_fmin was 3.37951 (3.35938) seconds

# %%
func.elapsed_iterations
# Out:
# 22360

# %%
f = lambda x: np.sin(3*np.pi*x[0])**2 + (x[0] - 1)**2 * (1 + np.sin(3*np.pi*x[1])) + (x[1]-1)**2*(1+np.sin(2*np.pi*x[1])**2)
func8 = function(f, "Lévi function N.13")
func = function(f,name)

np.random.seed(42)
func.init_cloud(np.array(np.random.normal(3,1,(2,50))))

func.minimize(max_iterations = 100000, var_epsilon = 0.00001, 
              learning_rate = 0.01,
              method = "swarm_derivfree",
              kernel_a = 0.01, alpha_init = 0, alpha_rate = 1, beta=0, gamma=1,
              verbose = False, track_history = track_history)

func_list[func.name] = func
#func.plot_everything(folder_name = func.name, f_dim = 2, log = True)
# Out:
# Convergence achieved - Particles are localized
#
# Function value at cloud mean: 1.0325110002633172e-05
# Function value evaluated 1115350 times
#
# The clock time (CPU time) for train_fmin was 4.51318 (4.51562) seconds

# %%
f = lambda x: -0.0001*np.power(np.abs(np.sin(x[0])*np.sin(x[1])*np.exp(np.abs(100 - np.sqrt(x[0]**2 + x[1]**2)/np.pi)))+1,0.1)
func = function(f, "Cross-in-Tray Function")

np.random.seed(42)
func.init_cloud(np.array(np.random.normal(3,2,(2,50))))

func.minimize(max_iterations = 100000, var_epsilon = 0.0001, 
              learning_rate = 0.01,
              method = "swarm_derivfree",
              kernel_a = 0.1, alpha_init = 0, alpha_rate = 1, beta=0, gamma=1,
              verbose = False, track_history = track_history)

func_list[func.name] = func
#func.plot_everything(folder_name = func.name, f_dim = 2, log = True)
# Out:
# Convergence achieved - Particles are localized
#
# Function value at cloud mean: -2.0625407902437436
# Function value evaluated 114050 times
#
# The clock time (CPU time) for train_fmin was 0.47101 (0.46875) seconds

# %%
f = lambda x: -(np.sin(x[0]-x[1])**2*np.sin(x[0]+x[1])**2)/(np.sqrt(x[0]**2 + x[1]**2))
func = function(f, "Keane Function")

np.random.seed(42)
func.init_cloud(np.array(np.random.normal(2,3,(2,50))))

func.minimize(max_iterations = 100000, var_epsilon = 0.0001, 
              learning_rate = 0.01,
              method = "swarm_derivfree",
              kernel_a = 0.1, alpha_init = 0, alpha_rate = 1, beta=0, gamma=1,
              verbose = False, track_history = track_history)

func_list[func.name] = func
#func.plot_everything(folder_name = func.name, f_dim = 2, log = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-81ddb7d15c5c> in <module>
#       3
#       4 np.random.seed(42)
# ----> 5 func.init_cloud(np.array(np.random.normal(np.array([2,2.1]),3,(2,50))))
#       6
#       7 func.minimize(max_iterations = 100000, var_epsilon = 0.0001,
#
# mtrand.pyx in numpy.random.mtrand.RandomState.normal()
#
# common.pyx in numpy.random.common.cont()
#
# common.pyx in numpy.random.common.cont_broadcast_2()
#
# __init__.pxd in numpy.PyArray_MultiIterNew3()
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape

# %%
f = lambda x: -np.cos(x[0])*np.cos(x[1])*np.exp(-(x[0]-np.pi)**2 - (x[1]-np.pi)**2)
func = function(f, "Easom Function")

#2D grid in [0,5]x[0,5] -> interesting -> for some function 2D grid is better than gaussian initializations
x=np.linspace(-2, 6, 10)
y=np.linspace(-2, 6, 10)
xx,yy=np.meshgrid(x,y)
coords=np.array((xx.ravel(), yy.ravel()))

func.init_cloud(coords)
#func.init_cloud(False, auto = True, search_space = np.array([[-5,-5],[5,5]]), N = 50, function_dim =2)    
    
func.minimize(max_iterations = 10000, var_epsilon = 0.0001, 
              learning_rate = 0.01,
              method = "swarm_derivfree", N_sample = False,
              kernel_a = 0.01, alpha_init = 0, alpha_rate = 1, beta=0, gamma_init=1, gamma_rate = 0,
              verbose = False, track_history = True)

func_list[func.name] = func
func.plot_everything(folder_name = func.name, f_dim = 2, log = True,limits =[0,np.pi*2,0,np.pi*2])
# Out:
# Maximum amount of iterations reached
#
# Function value at cloud mean: -0.999999978131905
# Function value evaluated 1000000 times
#
# The clock time (CPU time) for train_fmin was 17.15170 (17.12500) seconds
# C:\Users\Rafael Cabral\Anaconda3\lib\site-packages\matplotlib\ticker.py:2241: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   "Data has no positive values, and therefore cannot be "

# %%
func.elapsed_iterations
# Out:
# 1384

# %% [markdown]
# # >2D Function

# %%
N_dim=3
f = lambda x: np.sum([100*(x[i+1]-x[i]**2)**2 + (1-x[i])**2 for i in range(N_dim-1)],axis=0)
func = function(f, "Rosenbrock function 3D")

np.random.seed(42)
func.init_cloud(np.array(np.random.normal(-1,3,(N_dim,50))))

func.minimize(max_iterations = 100000, var_epsilon = 0.0001, 
              learning_rate = 0.0001,
              method = "swarm_derivfree",
              kernel_a = 0.001, alpha_init = 0, alpha_rate = 10, beta=0, gamma=1,
              verbose = False, track_history = False)

func_list[func.name] = func
#func.plot_everything(folder_name = func.name, f_dim = 10, log = True)
# Out:
# Convergence achieved - Particles are localized
#
# Function value at cloud mean: 0.017099848750030514
# Function value evaluated 3533050 times
#
# The clock time (CPU time) for train_fmin was 22.77416 (22.78125) seconds

# %%
N_dim=2
f = lambda x: np.sum(np.sin(x)**2 - np.exp(-np.sum(x**2)),axis = 0)*np.exp(-np.sum(np.sin(np.sqrt(np.abs(x)))**2))
func = function(f, "Xin-She Yang N. 4 Function")

np.random.seed(42)
func.init_cloud(np.array(np.random.normal(0,1,(N_dim,200))))

func.minimize(max_iterations = 100000, var_epsilon = 0.0001, 
              learning_rate = 0.01, N_sample = False,
              method = "swarm_derivfree",
              kernel_a = 0.1, alpha_init = 0, alpha_rate = 1, beta=0, gamma_init=1, gamma_rate = 0,
              verbose = False, track_history = False)

func_list[func.name] = func
func.plot_everything(folder_name = func.name, f_dim = 2, log = True)
# Out:
# Convergence achieved - Particles are localized
#
# Function value at cloud mean: -1.4324968129300335
# Function value evaluated 433200 times
#
# The clock time (CPU time) for train_fmin was 13.53574 (13.50000) seconds
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-a5e851c81b6f> in <module>
#      13
#      14 func_list[func.name] = func
# ---> 15 func.plot_everything(folder_name = func.name, f_dim = 2, log = True)
#
# ~\Desktop\KAUST\mlswarm\mlswarm\mlswarm.py in plot_everything(self, folder_name, f_dim, log, limits)
#     284             X, Y, z  = get_2D_plot_data(self, limits)
#     285             self.plot_function(save = True, file_name = folder_name + "/function.png", dimension2 = True, limits = limits, X = X, Y = Y, z = z)
# --> 286             self.plot_cloud_history(save = True, file_name = folder_name + "/cloud_history.png", dimension2 = True, limits = limits, X= X, Y = Y, z = z)
#     287
#     288         self.plot_cost_history(save = True, file_name = folder_name + "/cost_history.png")
#
# ~\Desktop\KAUST\mlswarm\mlswarm\mlswarm.py in plot_cloud_history(self, save, file_name, dimension2, limits, X, Y, z, log)
#     245                     plot_matrix(np.absolute(cloud_history), np.absolute(self.cloud_history_mean), 'Particle positions',  'Iteration t', r'$|x_i(t)|$', r'$|\bar{x} (t)|$', save,  file_name, True)
#     246             else:
# --> 247                 plot_2D_trajectory(self.cloud_history_mean, self.N, save, file_name, limits, self.cloud_history, X, Y, z)
#     248                 if log:
#     249                     plot_2D_trajectory(np.absolute(self.cloud_history_mean), self.N, save, file_name, limits, np.absolute(self.cloud_history), X, Y, z, True)
#
# ~\Desktop\KAUST\mlswarm\mlswarm\utils.py in plot_2D_trajectory(cloud_history_mean, N, save, file_name, limits, cloud_history, X, Y, z, log)
#     255     plt.title(r'Particle positions  $ x_i (t)$')
#     256
# --> 257     cloud_history_mean_x = [it[0] for it in cloud_history_mean]
#     258     cloud_history_mean_y = [it[1] for it in cloud_history_mean]
#     259     plt.plot(cloud_history_mean_x, cloud_history_mean_y, 'k-', lw = 2)
#
# TypeError: 'NoneType' object is not iterable

# %%
N_dim = 10
f = lambda x: np.sum([(x[i]**2 - i)**2 for i in range(N_dim)],axis=0)
func = function(f, "Qing Function")

np.random.seed(42)
func.init_cloud(np.array(np.random.normal(0,3,(N_dim,100))))

func.minimize(max_iterations = 100000, var_epsilon = 0.00001, 
              learning_rate = 0.01,
              method = "swarm_derivfree", N_sample = False,
              kernel_a = 0.01, alpha_init = 0, alpha_rate = 1, beta=0, gamma_init=1, gamma_rate = 0,
              verbose = False, track_history = track_history)

func_list[func.name] = func
func.plot_everything(folder_name = func.name, f_dim = 10, log = True,limits =[-3,3,-3,3])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-ea8c8faaccf1> in <module>
#      10               method = "swarm_derivfree",
#      11               kernel_a = 0.01, alpha_init = 0, alpha_rate = 1, beta=0, gamma=1,
# ---> 12               verbose = False, track_history = track_history)
#      13
#      14 func_list[func.name] = func
#
# TypeError: minimize() got an unexpected keyword argument 'gamma'

# %% [markdown]
# ## Summarizing Data

# %%
import pandas as pd

# %%
data_matrix = []
for func_name, func in func_list.items():
    header, parameters = func.get_all_parameters(False, "")
    data_matrix.append(parameters)

df = pd.DataFrame(data_matrix, columns = header)
df.to_csv("Images/Benchmarking Data.csv", sep=',',index=False)
df
# Out:
#                           name    N  cloud_var  \
# 0           Quadratic Function   50    0.00010
# 1               pol_and_cosine   50    0.00001
# 2             pol_and_cosine_2   50    0.00010
# 3       Gramacy & Lee Function   50    0.00010
# 4               Beale function   50    0.00001
# 5              Ackley function  100    0.00010
# 6       Schaffer function N. 2   50    0.00001
# 7       Cross-in-Tray Function   50    0.00010
# 8               Keane Function   50    0.00010
# 9           Drop-Wave Function  200    0.00010
# 10      Rosenbrock function 3D   50    0.00010
# 11  Xin-She Yang N. 4 Function  200    0.00010
# 12               Qing Function  100    0.00001
# 13              Easom Function  100    0.00010
#
#                                            cloud_mean  \
# 0                                           [0.00113]
# 1                                          [-0.00038]
# 2                                          [-0.00074]
# 3                                           [0.54876]
# 4                                   [2.88375 0.46791]
# 5                                 [-0.01013 -0.00758]
# 6                                   [0.9997  1.00144]
# 7                                   [1.36174 1.37172]
# 8                                   [1.39674 0.00178]
# 9                                   [0.45222 0.25652]
# 10                          [1.05195 1.10578 1.21714]
# 11                                  [0.05524 0.2179 ]
# 12  [-0.16246 -1.00408  1.41584  1.73316  2.0007  ...
# 13                                  [3.14167 3.14167]
#
#             cloud_mean_func     train_method  elapsed_iterations  \
# 0     1.281448982455905e-06  swarm_derivfree                 698
# 1     1.169809371093329e-05  swarm_derivfree               22238
# 2    2.1112577040249385e-05  swarm_derivfree                7065
# 3    -8.689942603533318e-01  swarm_derivfree                7022
# 4    2.5352705940708186e-03  swarm_derivfree                3145
# 5     4.003751734757799e-02  swarm_derivfree               22229
# 6    1.0325110002633172e-05  swarm_derivfree               22307
# 7   -2.0625407902437436e+00  swarm_derivfree                2281
# 8    -6.736477439223008e-01  swarm_derivfree                2223
# 9    -9.362420464336573e-01  swarm_derivfree               21524
# 10   1.7099848750030514e-02  swarm_derivfree               70661
# 11  -1.4323631461254684e+00  swarm_derivfree                2238
# 12    8.281051965259498e-04  swarm_derivfree               22323
# 13   -9.999999826052318e-01  swarm_derivfree                7069
#
#     function_evaluations  clock_time   cpu_time  max_iterations  var_epsilon  \
# 0                  34900    0.131262   0.140625           10000      0.00010
# 1                1111900    3.329723   3.328125          100000      0.00001
# 2                 353250    1.222113   1.218750           10000      0.00010
# 3                 351100    1.196806   1.203125          100000      0.00010
# 4                 157250    0.595483   0.593750           10000      0.00001
# 5                2222900    6.749119   6.671875          100000      0.00010
# 6                1115350    4.513176   4.515625          100000      0.00001
# 7                 114050    0.471012   0.468750          100000      0.00010
# 8                 111150    0.404571   0.406250          100000      0.00010
# 9                4304800   21.120800  21.062500          100000      0.00010
# 10               3533050   15.576793  15.562500          100000      0.00010
# 11                447600    2.628873   2.625000          100000      0.00010
# 12               2232300   24.498182  24.500000          100000      0.00001
# 13                706900    2.323724   2.312500           10000      0.00010
#
#     learning_rate  kernel_a  alpha_init  alpha_rate  beta  gamma
# 0          0.0100     1.000           0         1.0     0      1
# 1          0.0100     0.010           0         1.0     0      1
# 2          0.0100     0.001           0        10.0     0      1
# 3          0.0010     0.010           0        10.0     0     10
# 4          0.0010     1.000           0         5.0     0      1
# 5          0.0100     0.001           0         1.0     0      1
# 6          0.0100     0.010           0         1.0     0      1
# 7          0.0100     0.100           0         1.0     0      1
# 8          0.0100     0.100           0         1.0     0      1
# 9          0.0100     0.010           0         0.1     0      1
# 10         0.0001     0.001           0        10.0     0      1
# 11         0.0100     0.100           0         1.0     0      1
# 12         0.0100     0.010           0         1.0     0      1
# 13         0.0100     0.010           0         1.0     0      1
