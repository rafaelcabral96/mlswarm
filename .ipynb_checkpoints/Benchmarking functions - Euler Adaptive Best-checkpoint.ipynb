# %%
from mlswarm.mlswarm import function
import numpy as np
np.random.seed(42)

func_list = {}
track_history = False

# %% [markdown]
# ## 1D Functions

# %%
f = lambda x: np.take(x,0,axis=0)**2
func = function(f, "Quadratic Function")

func.init_cloud([[-1],[-0.5],[0.2],[2]])

func.minimize()

func_list[func.name] = func
func.plot_everything(folder_name = func.name, f_dim = 1, log = True)
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.00655 (0.03125) seconds
# Cloud mean: [-0.0058983]
# Function value at cloud mean: 3.478996506782837e-05
# Function value evaluated 64 times
# Best Particle at position: [0.00044148] with function value: 1.9490326288750485e-07
# C:\Users\Rafael Cabral\Anaconda3\lib\site-packages\matplotlib\figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "

# %%
f = lambda x: np.take(x,0, axis = 0)**2 - (np.cos(4 * np.pi *np.take(x,0, axis = 0)) - 1)
func = function(f, "pol_and_cosine")

func.init_cloud(np.linspace(-2,1,5)[:,np.newaxis])

func.minimize()

func_list[func.name] = func
func.plot_everything(folder_name = func.name, f_dim = 1, log = True)
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.01296 (0.01562) seconds
# Cloud mean: [-0.00106366]
# Function value at cloud mean: 9.045920959839052e-05
# Function value evaluated 105 times
# Best Particle at position: [0.00032696] with function value: 8.54780079525181e-06
# C:\Users\Rafael Cabral\Anaconda3\lib\site-packages\matplotlib\ticker.py:2241: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   "Data has no positive values, and therefore cannot be "

# %%
f = lambda x: np.take(x,0,axis=0)**4 - 2*(np.cos(2*np.pi*np.take(x,0,axis=0)) -1) - np.take(x,0,axis=0)**2
func = function(f, "pol_and_cosine_2")

func.init_cloud(np.linspace(-2,1.5,5)[:,np.newaxis])

func.minimize()

func_list[func.name] = func
func.plot_everything(folder_name = func.name, f_dim = 1, log = True, limits = [-2,2])
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.01542 (0.01562) seconds
# Cloud mean: [-0.97742352]
# Function value at cloud mean: -0.02256191170518984
# Function value evaluated 135 times
# Best Particle at position: [-0.97738876] with function value: -0.02256198772302087

# %%
f = lambda x: np.sin(10*np.pi*np.take(x,0,axis=0))/(2*np.take(x,0,axis=0)) + (np.take(x,0,axis=0)-1)**4
name = "Gramacy & Lee Function" 
func = function(f, name)

func.init_cloud(np.linspace(-1,1,6)[:,np.newaxis])

func.minimize({'var_epsilon': 0.01})

func_list[func.name] = func
func.plot_everything(folder_name = func.name, f_dim = 1, log = True, limits = [-2,2])
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.05632 (0.07812) seconds
# Cloud mean: [0.13411524]
# Function value at cloud mean: -2.711337568893529
# Function value evaluated 846 times
# Best Particle at position: [0.13430102] with function value: -2.7176349471911707

# %% [markdown]
# ## 2D Functions

# %%
f = lambda x: (1.5 - np.take(x,0,axis=0) + np.take(x,0,axis=0)*np.take(x,1,axis=0))**2 + (2.25 - np.take(x,0,axis=0) + np.take(x,0,axis=0)*np.take(x,1,axis=0)**2)**2 + (2.625 - np.take(x,0,axis=0) + np.take(x,0,axis=0)*np.take(x,1,axis=0)**3)**2
func = function(f, "Beale function")

x=np.linspace(-1, 2, 5)
y=np.linspace(-1, 2, 5)
xx,yy=np.meshgrid(x,y)
coords=np.array((xx.ravel(), yy.ravel())).T
func.init_cloud(coords)

func.minimize({'var_epsilon': 0.01})

func_list[func.name] = func
func.plot_everything(folder_name = func.name, f_dim = 2, log = True)
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.01459 (0.01562) seconds
# Cloud mean: [2.9835515  0.49843242]
# Function value at cloud mean: 0.0001900784014639704
# Function value evaluated 725 times
# Best Particle at position: [3.00534342 0.49955674] with function value: 7.672841149375674e-05

# %%
f = lambda x: -20* np.exp(-0.2*np.sqrt(0.5*(np.take(x,0,axis=0)**2 + np.take(x,1,axis=0)**2))) - np.exp(0.5*(np.cos(2*np.pi*np.take(x,0,axis=0))+np.cos(2*np.pi*np.take(x,1,axis=0)))) + np.exp(1) + 20
func = function(f,"Ackley function")

x=np.linspace(-1, 2, 3)
y=np.linspace(-1, 2, 3)
xx,yy=np.meshgrid(x,y)
coords=np.array((xx.ravel(), yy.ravel())).T
func.init_cloud(coords)

func.minimize({'var_epsilon': 0.000001})

func_list[func.name] = func
func.plot_everything(folder_name = func.name, f_dim = 2, log = True)
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.01417 (0.00000) seconds
# Cloud mean: [-6.90297055e-06  4.81008819e-06]
# Function value at cloud mean: 2.3799019373882402e-05
# Function value evaluated 270 times
# Best Particle at position: [-9.68935441e-06  1.07889260e-05] with function value: 4.102115880755264e-05

# %%
f = lambda x: 0.5 + (np.sin(np.take(x,0,axis=0)**2 - np.take(x,1,axis=0)**2)**2 - 0.5)/(1 +0.01*(np.take(x,0,axis=0)**2 + np.take(x,1,axis=0)**2)**2)
func = function(f,"Schaffer function N. 2")

x=np.linspace(-1, 2, 3)
y=np.linspace(-1, 2, 3)
xx,yy=np.meshgrid(x,y)
coords=np.array((xx.ravel(), yy.ravel())).T
func.init_cloud(coords)

func.minimize()

func_list[func.name] = func
func.plot_everything(folder_name = func.name, f_dim = 2, log = True)
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.01212 (0.01562) seconds
# Cloud mean: [-5.1252038e-05 -5.1252038e-05]
# Function value at cloud mean: 0.0
# Function value evaluated 252 times
# Best Particle at position: [-0.00036782 -0.00036782] with function value: 3.3306690738754696e-16

# %%
f = lambda x: np.sin(3*np.pi*x[0])**2 + (x[0] - 1)**2 * (1 + np.sin(3*np.pi*x[1])) + (x[1]-1)**2*(1+np.sin(2*np.pi*x[1])**2)
func = function(f,"Lévi function N.13")

x=np.linspace(-1, 2, 3)
y=np.linspace(-1, 2, 3)
xx,yy=np.meshgrid(x,y)
coords=np.array((xx.ravel(), yy.ravel())).T
func.init_cloud(coords)

func.minimize({'var_epsilon': 0.00001})

func_list[func.name] = func
func.plot_everything(folder_name = func.name, f_dim = 2, log = True)
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.02024 (0.01562) seconds
# Cloud mean: [0.99988842 0.99208161]
# Function value at cloud mean: 6.397523592681415e-05
# Function value evaluated 504 times
# Best Particle at position: [0.99999766 0.9928476 ] with function value: 5.1260599936574846e-05

# %%
f = lambda x: -0.0001*np.power(np.abs(np.sin(x[0])*np.sin(x[1])*np.exp(np.abs(100 - np.sqrt(x[0]**2 + x[1]**2)/np.pi)))+1,0.1)
func = function(f, "Cross-in-Tray Function")

x=np.linspace(-1, 2, 3)
y=np.linspace(-1, 2, 3)
xx,yy=np.meshgrid(x,y)
coords=np.array((xx.ravel(), yy.ravel())).T
func.init_cloud(coords)

func.minimize({'var_epsilon': 0.1})

func_list[func.name] = func
func.plot_everything(folder_name = func.name, f_dim = 2, log = True)
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.00948 (0.01562) seconds
# Cloud mean: [1.39343769 1.40968043]
# Function value at cloud mean: -2.0620106560063336
# Function value evaluated 180 times
# Best Particle at position: [1.39094497 1.4123935 ] with function value: -2.0619961569047303

# %%
f = lambda x: -(np.sin(x[0]-x[1])**2*np.sin(x[0]+x[1])**2)/(np.sqrt(x[0]**2 + x[1]**2))
func = function(f, "Keane Function")

x=np.linspace(-1, 2, 3)
y=np.linspace(-1, 2, 3)
xx,yy=np.meshgrid(x,y)
coords=np.array((xx.ravel(), yy.ravel())).T
func.init_cloud(coords)

func.minimize({'var_epsilon': 0.01})

func_list[func.name] = func
func.plot_everything(folder_name = func.name, f_dim = 2, log = True)
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.02953 (0.03125) seconds
# Cloud mean: [-0.03135397  1.42437219]
# Function value at cloud mean: -0.6709794392552887
# Function value evaluated 558 times
# Best Particle at position: [-0.02784358  1.42289835] with function value: -0.6714064981540986

# %%
f = lambda x: -np.cos(x[0])*np.cos(x[1])*np.exp(-(x[0]-np.pi)**2 - (x[1]-np.pi)**2)
func = function(f, "Easom Function")

x=np.linspace(-2, 6, 3)
y=np.linspace(-2, 6, 3)
xx,yy=np.meshgrid(x,y)
coords=np.array((xx.ravel(), yy.ravel())).T

func.init_cloud(coords)

func.minimize({'var_epsilon': 0.01})

func_list[func.name] = func
func.plot_everything(folder_name = func.name, f_dim = 2, log = True,limits =[0,np.pi*2,0,np.pi*2])
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.03350 (0.03125) seconds
# Cloud mean: [3.12533076 3.12533076]
# Function value at cloud mean: -0.9992069556732626
# Function value evaluated 846 times
# Best Particle at position: [3.12180576 3.12180576] with function value: -0.9988261008653214

# %% [markdown]
# # >2D Function

# %%
N_dim=2
f = lambda x: np.sum([100*(x[i+1]-x[i]**2)**2 + (1-x[i])**2 for i in range(N_dim-1)],axis=0)
func = function(f, "Rosenbrock function 3D")

#np.random.seed(42)
x=np.linspace(-1, 2, 5)
y=np.linspace(-1, 2, 5)
xx,yy=np.meshgrid(x,y)
coords=np.array((xx.ravel(), yy.ravel())).T

func.init_cloud(coords)

func.minimize({'var_epsilon': 0.01})

func.plot_everything(folder_name = func.name, f_dim = 2, log = True)
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.03205 (0.03125) seconds
# Cloud mean: [0.9302289  0.86680887]
# Function value at cloud mean: 0.0050879525055726885
# Function value evaluated 1575 times
# Best Particle at position: [0.9683996  0.93548067] with function value: 0.0015354861676959673

# %%
N_dim=5
f = lambda x: (np.sin(x[0])**2+ np.sin(x[1])**2 - np.exp(-x[0]**2 - x[1]**2))*np.exp(-np.sin(np.sqrt(np.abs(x[0])))**2- np.sin(np.sqrt(np.abs(x[1])))**2)
func = function(f, "Xin-She Yang N. 4 Function")

np.random.seed(42)
func.init_cloud(np.array(np.random.normal(1,2,(30,N_dim))))

func.minimize({'var_epsilon': 0.01})

func_list[func.name] = func
func.plot_everything(folder_name = func.name, f_dim = 5, log = True)
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.03787 (0.03125) seconds
# Cloud mean: [ 0.02341567 -0.0094122   1.68300094 -3.27472968 -2.75880404]
# Function value at cloud mean: -0.9666774008062905
# Function value evaluated 2010 times
# Best Particle at position: [ 9.11994974e-03  4.28839253e-04  1.66990898e+00 -3.27315285e+00
#  -2.76553768e+00] with function value: -0.9903590153939473

# %%
N_dim = 3
f = lambda x: np.sum([(x[i]**2 - i)**2 for i in range(N_dim)],axis=0)
func = function(f, "Qing Function")

func.init_cloud(np.array(np.random.normal(0,3,(20, N_dim))))

func.minimize({'var_epsilon': 0.0001})

func_list[func.name] = func
func.plot_everything(folder_name = func.name, f_dim = 3, log = True,limits =[-3,3,-3,3])
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.02954 (0.03125) seconds
# Cloud mean: [-0.05781871  1.00051871 -1.41335534]
# Function value at cloud mean: 1.8141303474888622e-05
# Function value evaluated 940 times
# Best Particle at position: [-0.04670276  0.99947449 -1.41318747] with function value: 1.4278245500325943e-05

# %% [markdown]
# ## Summarizing Data

# %%
import pandas as pd

# %%
data_matrix = []
for func_name, func in func_list.items():
    header, parameters = func.get_all_parameters(False, "")
    data_matrix.append(parameters)

df = pd.DataFrame(data_matrix, columns = header)
df.to_csv("Images/Benchmarking.csv", sep=',',index=False)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-840d86aca5ee> in <module>
#       1 data_matrix = []
# ----> 2 for func_name, func in func_list.items():
#       3     header, parameters = func.get_all_parameters(False, "")
#       4     data_matrix.append(parameters)
#       5
#
# NameError: name 'func_list' is not defined
