# %% [markdown]
# The goal here is to do logistic regression on the Iris Dataset.
#
# There are 4 atributes are 3 possible classes
#
# Logistic Regression is basically a single layer neural network with sigmoid or sofmax activation function

# %%
from mlswarm.mlswarm import neuralnet 
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd

#DATASET-------------------------------
data = pd.read_csv('Datasets/iris.data', header = None)
data.loc[:,4] = pd.Categorical(data.loc[:,4])
data_X = data.loc[:, 0:3].values
data_Y = pd.get_dummies(data.loc[:,4], prefix = 'category').values

#Split into train and test
X_train, X_test, Y_train, Y_test = train_test_split(data_X, data_Y, test_size=0.1, random_state=42)

# %%
nn_architecture = [
    {"input_dim": 4, "output_dim": 3, "activation": "softmax"}
]

#CREATE NEURAL NETWORK
nn = neuralnet(nn_architecture)

#INITIALIZE CLOUD WITH 5 PARTICLES ACCORDING TO XAVIER INITIALIZATION
nn.init_cloud(N = 50)

#TRAINING
nn.train(X_train, Y_train, {'learning_rate': 0.1,
                            'cost_type': 'cross_entropy_softmax',
                            'max_epochs': 1000,
                            'kernel_a': 0.01,
                            'verbose': True})
# Out:
# Training started...
# [[3.35564047 8.30711052 0.58776719]
#  [5.09849383 5.53072657 3.36550253]
#  [6.64119178 3.885349   5.01239951]]
# [[[ 2.32759129  1.51845927  1.98371262]
#   [ 2.6067329   1.16845293  3.97713801]
#   [ 2.59054159  1.18454506  5.31415608]]
#
#  [[ 2.7974761   2.47691615  0.12948679]
#   [ 3.92522488  1.38066353  1.22528133]
#   [ 5.23490032  0.72366441  1.88226327]]
#
#  [[ 3.07659824  3.33292612  0.59960757]
#   [ 2.17807315  1.82926135  1.65252678]
#   [ 2.03848594  1.6596903   2.26927429]]
#
#  [[ 1.3727348   5.32536171  4.1312875 ]
#   [ 1.81719585  5.22519159  3.68684081]
#   [ 2.32136297  6.27601817  3.18266361]]
#
#  [[ 6.92793618  2.7015193   2.67678528]
#   [ 6.26000577  3.15653494  3.94923255]
#   [ 5.58671565  3.81784488  4.90262145]]
#
#  [[ 5.62802854  0.693426    1.74668091]
#   [ 3.94268693  2.41507649  2.97989216]
#   [ 2.99421355  3.35441151  4.05070293]]
#
#  [[ 5.90383798  3.52115557 17.10748492]
#   [ 8.35530738  7.47724718 13.17616586]
#   [10.29500054  9.72559202 10.97295819]]
#
#  [[ 4.24261383  3.70803391  8.29584021]
#   [ 3.94402591  4.51704876  8.05485102]
#   [ 4.42194351  5.54032685  7.53717686]]
#
#  [[ 3.80875812  9.84714844  4.73708965]
#   [ 5.42829193  9.02575129  4.64267261]
#   [ 6.88578528  8.39881125  5.24088869]]
#
#  [[ 2.44573734  1.63751309  0.55932979]
#   [ 0.74019502  1.18021625  1.87018432]
#   [ 0.33879763  1.58784185  2.24246924]]
#
#  [[ 1.78031387  4.10516446  0.32238953]
#   [ 2.50598438  2.6244852   1.82727433]
#   [ 3.43547449  1.94712845  2.49780918]]
#
#  [[ 3.10920139 11.19130517  7.11337514]
#   [ 4.83622216  9.46433496  7.81304132]
#   [ 6.35525799  7.94533534  9.41678538]]
#
#  [[ 5.06554145  0.08079717  6.32934644]
#   [ 6.14512443  2.75328761  3.65685854]
#   [ 7.68741553  4.11588485  2.29426327]]
#
#  [[ 4.29225551  2.05688475  6.96054247]
#   [ 7.50230866  3.13228236  5.88470768]
#   [ 9.64064637  3.82893419  5.18805426]]
#
#  [[ 0.35904314  1.60547271  2.55200596]
#   [ 1.12033542  2.27471798  1.7860344 ]
#   [ 1.61319826  3.07289784  1.28946088]]
#
#  [[ 4.97223744  1.82483253  3.14404333]
#   [ 7.938162    4.26156006  5.94485583]
#   [ 6.71748664  5.48237831  7.28876429]]
#
#  [[ 6.10067014  3.66570986 10.96089568]
#   [ 6.27053821  4.87466668  9.75691247]
#   [ 7.33535953  6.10303857  8.5349114 ]]
#
#  [[ 3.74048667  3.09437377  5.61439028]
#   [ 2.73823988  4.11340319  5.93117905]
#   [ 2.88327555  5.21387093  5.78040756]]
#
#  [[ 2.84526639  0.3329368   4.30423014]
#   [ 1.8568552   1.32134417  6.31766496]
#   [ 1.46626345  1.7119358   7.96333461]]
#
#  [[ 0.12055146  1.17259959  2.86188213]
#   [ 1.33924475  3.05502713  1.58166963]
#   [ 2.01760351  4.42571313  0.90286485]]
#
#  [[ 0.27948354  5.57071543  1.97620664]
#   [ 0.9737023   7.35088031  1.28198771]
#   [ 1.30141349  9.41088305  0.95427651]]
#
#  [[ 2.2930556   1.62169591  4.4457289 ]
#   [ 2.32239469  2.10939583  4.05841862]
#   [ 2.82291331  2.67120795  3.54269135]]
#
#  [[ 1.66660086  4.66182287  4.13351543]
#   [ 2.06493571  4.26330345  6.28860684]
#   [ 2.6001676   3.72807038  7.95991098]]
#
#  [[ 3.95375204  0.81551058  4.02586086]
#   [ 3.08841871  1.68317492  3.35090713]
#   [ 2.46282955  2.31188076  3.83759814]]
#
#  [[ 1.97696222  0.33178374  1.42608221]
#   [ 2.58386007  1.00159282  0.75040342]
#   [ 3.20310735  1.32101724  0.43065291]]
#
#  [[ 4.24621734  3.2684972   2.42929953]
#   [ 3.93643923  1.39822887  4.28419286]
#   [ 4.44317727  1.0618698   4.62039576]]
#
#  [[ 3.35564047  8.30711052  0.58776719]
#   [ 5.09849383  5.53072657  3.36550253]
#   [ 6.64119178  3.885349    5.01239951]]]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-0dd54b82c4cb> in <module>
#      14                             'max_epochs': 1000,
#      15                             'kernel_a': 0.01,
# ---> 16                             'verbose': True})
#
# ~\Desktop\KAUST\mlswarm\mlswarm\mlswarm.py in train(self, X, Y, parameters_dic)
#     102
#     103         #start training
# --> 104         train_nn(*parameters)
#     105         #train_nn2(self, X.T, Y.T, "swarm_derivfree", max_epochs = 20, n_batches = 1, batch_size = X.shape[0], learning_rate=0.1, cost_type = 'rmse', kernel_a = 0.01,  alpha_init = 0, alpha_rate = 1, beta = 0, gamma = 0, verbose = True, var_epsilon = 0)
#     106
#
# ~\Desktop\KAUST\mlswarm\mlswarm\utils.py in function_timer(*args, **kwargs)
#      13         start_cputime = time.process_time()
#      14
# ---> 15         value = func(*args, **kwargs)
#      16
#      17         end_cputime = time.process_time()
#
# ~\Desktop\KAUST\mlswarm\mlswarm\train.py in train_nn(self, X, Y, method, max_epochs, n_batches, batch_size, lr, cost_type, kernel_a, alpha_init, alpha_rate, beta, gamma_init, verbose, var_epsilon)
#     170             if new_min < self.best_cost:
#     171                 self.best_cost = new_min
# --> 172                 self.best_nn = self.cloud[np.nanargmin(costs)]
#     173
#     174             #compute update and cloud variance--------------------------------------
#
# IndexError: list index out of range

# %%
#PLOT COST HISTORY
nn.plot_cost_history()

#ACCURACY ON TEST SET USING PARTICLE 0 WEIGHTS
nn.prediction_accuracy_particle(X_test, Y_test, acc_type = "accuracy_multiclass", particle = 0)

#ACCURACY ON TEST SET USING CLOUD MEAN WEIGHTS
nn.prediction_accuracy_mean_particle(X_test, Y_test, acc_type = "accuracy_multiclass")
# Out:
# Test set accuracy using neuralnet 0: 0.86667
# Test set accuracy using cloud mean: 0.66667
