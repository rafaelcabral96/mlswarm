# %%
from mlswarm.mlswarm import function
import numpy as np
np.random.seed(42)

func_list = {}
track_history = False

# %% [markdown]
# ## 1D Functions

# %%
f = lambda x: np.take(x,0,axis=0)**2
func = function(f, "Quadratic Function")

func.init_cloud([[-1],[-0.5],[0.2],[2]])

func.minimize({'algorithm':'nesterov',
               'learning_rate':0.1})

func_list[func.name] = func
func.plot_everything(folder_name = func.name, f_dim = 1, log = True)
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.00426 (0.00000) seconds
# Cloud mean: [0.00299071]
# Function value at cloud mean: 8.944344498696338e-06
# Function value evaluated 52 times
# Best Particle at position: [-0.00071271] with function value: 5.079550972575753e-07
# C:\Users\Rafael Cabral\Anaconda3\lib\site-packages\matplotlib\figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "

# %%
f = lambda x: np.take(x,0, axis = 0)**2 - (np.cos(4 * np.pi *np.take(x,0, axis = 0)) - 1)
func = function(f, "pol_and_cosine")

func.init_cloud(np.linspace(-2,1,5)[:,np.newaxis])

func.minimize({'algorithm':'nesterov'})

func_list[func.name] = func
func.plot_everything(folder_name = func.name, f_dim = 1, log = True)
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.00777 (0.01562) seconds
# Cloud mean: [-0.00403311]
# Function value at cloud mean: 0.0013003015397154395
# Function value evaluated 115 times
# Best Particle at position: [-0.00048888] with function value: 1.910994538990948e-05

# %%
f = lambda x: np.take(x,0,axis=0)**4 - 2*(np.cos(2*np.pi*np.take(x,0,axis=0)) -1) - np.take(x,0,axis=0)**2
func = function(f, "pol_and_cosine_2")

func.init_cloud(np.linspace(-2,1.5,5)[:,np.newaxis])

func.minimize({'algorithm':'nesterov'})

func_list[func.name] = func
func.plot_everything(folder_name = func.name, f_dim = 1, log = True, limits = [-2,2])
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.00976 (0.00000) seconds
# Cloud mean: [-0.96301246]
# Function value at cloud mean: -0.013568316259951918
# Function value evaluated 125 times
# Best Particle at position: [-0.97444323] with function value: -0.022184229908210118

# %%
f = lambda x: np.sin(10*np.pi*np.take(x,0,axis=0))/(2*np.take(x,0,axis=0)) + (np.take(x,0,axis=0)-1)**4
name = "Gramacy & Lee Function" 
func = function(f, name)

func.init_cloud(np.linspace(-1,1,6)[:,np.newaxis])

func.minimize({'algorithm':'nesterov',
               'learning_rate': 0.001, 
               'var_epsilon':0.01})

func_list[func.name] = func
#func.plot_everything(folder_name = func.name, f_dim = 1, log = True, limits = [-2,2])
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.02052 (0.03125) seconds
# Cloud mean: [0.12539349]
# Function value at cloud mean: -2.269062106188686
# Function value evaluated 264 times
# Best Particle at position: [0.14418421] with function value: -2.8736254458257644

# %% [markdown]
# ## 2D Functions

# %%
f = lambda x: (1.5 - np.take(x,0,axis=0) + np.take(x,0,axis=0)*np.take(x,1,axis=0))**2 + (2.25 - np.take(x,0,axis=0) + np.take(x,0,axis=0)*np.take(x,1,axis=0)**2)**2 + (2.625 - np.take(x,0,axis=0) + np.take(x,0,axis=0)*np.take(x,1,axis=0)**3)**2
func = function(f, "Beale function")

x=np.linspace(-1, 2, 5)
y=np.linspace(-1, 2, 5)
xx,yy=np.meshgrid(x,y)
coords=np.array((xx.ravel(), yy.ravel())).T
func.init_cloud(coords)

func.minimize({'algorithm':'nesterov',
               'var_epsilon': 0.01,
               'learning_rate': 0.001})

func_list[func.name] = func
#func.plot_everything(folder_name = func.name, f_dim = 2, log = True)
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.05350 (0.04688) seconds
# Cloud mean: [3.04875666 0.5156089 ]
# Function value at cloud mean: 0.0007112158994197863
# Function value evaluated 2625 times
# Best Particle at position: [3.00616388 0.5001007 ] with function value: 5.307868674922759e-05

# %%
f = lambda x: -20* np.exp(-0.2*np.sqrt(0.5*(np.take(x,0,axis=0)**2 + np.take(x,1,axis=0)**2))) - np.exp(0.5*(np.cos(2*np.pi*np.take(x,0,axis=0))+np.cos(2*np.pi*np.take(x,1,axis=0)))) + np.exp(1) + 20
func = function(f,"Ackley function")

x=np.linspace(-1, 2, 3)
y=np.linspace(-1, 2, 3)
xx,yy=np.meshgrid(x,y)
coords=np.array((xx.ravel(), yy.ravel())).T
func.init_cloud(coords)

func.minimize({'algorithm':'nesterov'})

func_list[func.name] = func
#func.plot_everything(folder_name = func.name, f_dim = 2, log = True)
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.01903 (0.00000) seconds
# Cloud mean: [-0.00173342 -0.00155878]
# Function value at cloud mean: 0.006738347520663268
# Function value evaluated 342 times
# Best Particle at position: [-1.76209689e-03  6.25563428e-05] with function value: 0.005069885180475353

# %%
f = lambda x: 0.5 + (np.sin(np.take(x,0,axis=0)**2 - np.take(x,1,axis=0)**2)**2 - 0.5)/(1 +0.01*(np.take(x,0,axis=0)**2 + np.take(x,1,axis=0)**2)**2)
func = function(f,"Schaffer function N. 2")

x=np.linspace(-1, 2, 3)
y=np.linspace(-1, 2, 3)
xx,yy=np.meshgrid(x,y)
coords=np.array((xx.ravel(), yy.ravel())).T
func.init_cloud(coords)

func.minimize({'algorithm':'nesterov'})

func_list[func.name] = func
#func.plot_everything(folder_name = func.name, f_dim = 2, log = True)
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.03120 (0.04688) seconds
# Cloud mean: [-0.00137973 -0.00137973]
# Function value at cloud mean: 7.249756350802272e-14
# Function value evaluated 540 times
# Best Particle at position: [0.00061257 0.00061257] with function value: 2.7755575615628914e-15

# %%
f = lambda x: np.sin(3*np.pi*x[0])**2 + (x[0] - 1)**2 * (1 + np.sin(3*np.pi*x[1])) + (x[1]-1)**2*(1+np.sin(2*np.pi*x[1])**2)
func = function(f,"Lévi function N.13")

x=np.linspace(-1, 2, 3)
y=np.linspace(-1, 2, 3)
xx,yy=np.meshgrid(x,y)
coords=np.array((xx.ravel(), yy.ravel())).T
func.init_cloud(coords)

func.minimize({'algorithm':'nesterov'})

func_list[func.name] = func
#func.plot_everything(folder_name = func.name, f_dim = 2, log = True)
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.01894 (0.03125) seconds
# Cloud mean: [0.99986089 0.9934846 ]
# Function value at cloud mean: 4.4260851827561585e-05
# Function value evaluated 549 times
# Best Particle at position: [0.99942439 0.99897527] with function value: 3.081511506710238e-05

# %%
f = lambda x: -0.0001*np.power(np.abs(np.sin(x[0])*np.sin(x[1])*np.exp(np.abs(100 - np.sqrt(x[0]**2 + x[1]**2)/np.pi)))+1,0.1)
func = function(f, "Cross-in-Tray Function")

x=np.linspace(-1, 2, 3)
y=np.linspace(-1, 2, 3)
xx,yy=np.meshgrid(x,y)
coords=np.array((xx.ravel(), yy.ravel())).T
func.init_cloud(coords)

func.minimize({'algorithm':'nesterov',
               'var_epsilon':0.01})

func_list[func.name] = func
#func.plot_everything(folder_name = func.name, f_dim = 2, log = True)
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.05104 (0.06250) seconds
# Cloud mean: [1.31585969 1.31585969]
# Function value at cloud mean: -2.0623667192225206
# Function value evaluated 1413 times
# Best Particle at position: [1.34828348 1.34828348] with function value: -2.062611597409964

# %%
f = lambda x: -(np.sin(x[0]-x[1])**2*np.sin(x[0]+x[1])**2)/(np.sqrt(x[0]**2 + x[1]**2))
func = function(f, "Keane Function")

x=np.linspace(-1, 2, 3)
y=np.linspace(-1, 2, 3)
xx,yy=np.meshgrid(x,y)
coords=np.array((xx.ravel(), yy.ravel())).T
func.init_cloud(coords)

func.minimize({'algorithm': 'nesterov',
               'var_epsilon': 0.01})

func_list[func.name] = func
#func.plot_everything(folder_name = func.name, f_dim = 2, log = True)
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.02701 (0.03125) seconds
# Cloud mean: [0.0057017  1.39210278]
# Function value at cloud mean: -0.6736150431337736
# Function value evaluated 540 times
# Best Particle at position: [-2.20042394e-04  1.39809325e+00] with function value: -0.6736388928338055

# %%
f = lambda x: -np.cos(x[0])*np.cos(x[1])*np.exp(-(x[0]-np.pi)**2 - (x[1]-np.pi)**2)
func = function(f, "Easom Function")

x=np.linspace(-2, 6, 3)
y=np.linspace(-2, 6, 3)
xx,yy=np.meshgrid(x,y)
coords=np.array((xx.ravel(), yy.ravel())).T

func.init_cloud(coords)

func.minimize({'algorithm': 'nesterov',
               'var_epsilon': 0.01})

func_list[func.name] = func
#func.plot_everything(folder_name = func.name, f_dim = 2, log = True,limits =[0,np.pi*2,0,np.pi*2])
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.02974 (0.03125) seconds
# Cloud mean: [3.14842015 3.15132315]
# Function value at cloud mean: -0.9997880757698815
# Function value evaluated 819 times
# Best Particle at position: [3.14497071 3.14787308] with function value: -0.9999237202520009

# %% [markdown]
# # >2D Function

# %%
N_dim=2
f = lambda x: np.sum([100*(x[i+1]-x[i]**2)**2 + (1-x[i])**2 for i in range(N_dim-1)],axis=0)
func = function(f, "Rosenbrock function 3D")

#np.random.seed(42)
x=np.linspace(-1, 2, 5)
y=np.linspace(-1, 2, 5)
xx,yy=np.meshgrid(x,y)
coords=np.array((xx.ravel(), yy.ravel())).T

func.init_cloud(coords)

func.minimize({'algorithm': 'nesterov',
               'learning_rate': 0.0001,
               'var_epsilon': 0.01})

func_list[func.name] = func
#func.plot_everything(folder_name = func.name, f_dim = 2, log = True)
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.09777 (0.10938) seconds
# Cloud mean: [1.02310689 1.03787104]
# Function value at cloud mean: 0.0084134521539695
# Function value evaluated 6425 times
# Best Particle at position: [1.00056667 1.0002109 ] with function value: 8.54685239521366e-05

# %%
N_dim=5
f = lambda x: (np.sin(x[0])**2+ np.sin(x[1])**2 - np.exp(-x[0]**2 - x[1]**2))*np.exp(-np.sin(np.sqrt(np.abs(x[0])))**2- np.sin(np.sqrt(np.abs(x[1])))**2)
func = function(f, "Xin-She Yang N. 4 Function")

np.random.seed(42)
func.init_cloud(np.array(np.random.normal(1,2,(30,N_dim))))

func.minimize({'algorithm': 'nesterov',
               'learning_rate': 0.01,
               'var_epsilon': 0.01})

func_list[func.name] = func
#func.plot_everything(folder_name = func.name, f_dim = 5, log = True)
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.01933 (0.01562) seconds
# Cloud mean: [ 0.00601933 -0.00840552  1.44589941 -3.41665402 -2.72624199]
# Function value at cloud mean: -0.985503062637185
# Function value evaluated 1230 times
# Best Particle at position: [ 1.26933069e-03  8.31788873e-05  1.46856231e+00 -3.35679526e+00
#  -2.69818695e+00] with function value: -0.9986457113448491

# %%
N_dim = 3
f = lambda x: np.sum([(x[i]**2 - i)**2 for i in range(N_dim)],axis=0)
func = function(f, "Qing Function")

func.init_cloud(np.array(np.random.normal(0,3,(20, N_dim))))

func.minimize({'algorithm': 'nesterov',
               'learning_rate': 0.01,
               'var_epsilon': 0.001})

func_list[func.name] = func
#func.plot_everything(folder_name = func.name, f_dim = 3, log = True,limits =[-3,3,-3,3])
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.02620 (0.01562) seconds
# Cloud mean: [-0.01399488  0.99769048 -1.41335875]
# Function value at cloud mean: 2.7166645023967192e-05
# Function value evaluated 1260 times
# Best Particle at position: [-0.00363318  0.99615692 -1.41397246] with function value: 5.931548366873877e-05

# %% [markdown]
# ## Summarizing Data

# %%
import pandas as pd

# %%
data_matrix = []
for func_name, func in func_list.items():
    header, parameters = func.get_all_parameters(False, "")
    data_matrix.append(parameters)

df = pd.DataFrame(data_matrix, columns = header)
df.to_csv("Images/Benchmarking.csv", sep=',',index=False)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-840d86aca5ee> in <module>
#       1 data_matrix = []
# ----> 2 for func_name, func in func_list.items():
#       3     header, parameters = func.get_all_parameters(False, "")
#       4     data_matrix.append(parameters)
#       5
#
# NameError: name 'func_list' is not defined
