# %% [markdown]
# The goal is to do binary classification on the make_moons dataset from sklearn.
#
# It is utilized a neural nerwork based on relu and sigmoid activation functions

# %%
from mlswarm.mlswarm import neuralnet 

#DATASET-------------------------------
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split
X, Y = make_moons(n_samples = 2000, noise=0.2, random_state=100)
Y = Y.reshape((Y.shape[0],1))
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state = 42)

# %%
nn_architecture = [
    {"input_dim": 2, "output_dim": 5, "activation": "relu"},
    {"input_dim": 5, "output_dim": 10, "activation": "relu"},
    {"input_dim": 10, "output_dim": 5, "activation": "relu"},
    {"input_dim": 5, "output_dim": 1, "activation": "sigmoid"},
]

#CREATE NEURAL NETWORK
nn = neuralnet(nn_architecture)

#INITIALIZE CLOUD WITH 150 PARTICLES ACCORDING TO XAVIER INITIALIZATION
nn.init_cloud(N = 150)

#TRAINING
nn.train(X = X_train, Y = Y_train, 
         method = "swarm_derivfree", 
         max_epochs= 500, n_batches = , batch_size = X_train.size[0],
         learning_rate = 1, var_epsilon = 0,
         cost_type = "rmse", #or cross_entropy_binary
         kernel_a = 0.01, alpha_init = 0, alpha_rate = 1, beta = 0, gamma = 1, 
         verbose = True)
# Out:
# Training started...
# Iteration: 00000 - Cloud mean cost: 0.26998 - Cloud variance: 0.45914
# Iteration: 00001 - Cloud mean cost: 0.26520 - Cloud variance: 0.42779
# Iteration: 00002 - Cloud mean cost: 0.25858 - Cloud variance: 0.38756
# Iteration: 00003 - Cloud mean cost: 0.25096 - Cloud variance: 0.34282
# Iteration: 00004 - Cloud mean cost: 0.24287 - Cloud variance: 0.29779
# Iteration: 00005 - Cloud mean cost: 0.23512 - Cloud variance: 0.25570
# Iteration: 00006 - Cloud mean cost: 0.22819 - Cloud variance: 0.21839
# Iteration: 00007 - Cloud mean cost: 0.22238 - Cloud variance: 0.18649
# Iteration: 00008 - Cloud mean cost: 0.21806 - Cloud variance: 0.15981
# Iteration: 00009 - Cloud mean cost: 0.21507 - Cloud variance: 0.13774
# Iteration: 00010 - Cloud mean cost: 0.21311 - Cloud variance: 0.11955
# Iteration: 00011 - Cloud mean cost: 0.21210 - Cloud variance: 0.10452
# Iteration: 00012 - Cloud mean cost: 0.21185 - Cloud variance: 0.09205
# Iteration: 00013 - Cloud mean cost: 0.21225 - Cloud variance: 0.08164
# Iteration: 00014 - Cloud mean cost: 0.21316 - Cloud variance: 0.07289
# Iteration: 00015 - Cloud mean cost: 0.21445 - Cloud variance: 0.06548
# Iteration: 00016 - Cloud mean cost: 0.21597 - Cloud variance: 0.05915
# Iteration: 00017 - Cloud mean cost: 0.21749 - Cloud variance: 0.05371
# Iteration: 00018 - Cloud mean cost: 0.21891 - Cloud variance: 0.04900
# Iteration: 00053 - Cloud mean cost: 0.00016 - Cloud variance: 0.00783
# Iteration: 00054 - Cloud mean cost: 0.00015 - Cloud variance: 0.00756
# Iteration: 00055 - Cloud mean cost: 0.00014 - Cloud variance: 0.00732
# Iteration: 00056 - Cloud mean cost: 0.00013 - Cloud variance: 0.00708
# Iteration: 00057 - Cloud mean cost: 0.00012 - Cloud variance: 0.00685
# Iteration: 00058 - Cloud mean cost: 0.00011 - Cloud variance: 0.00664
# Iteration: 00059 - Cloud mean cost: 0.00011 - Cloud variance: 0.00643
# Iteration: 00060 - Cloud mean cost: 0.00010 - Cloud variance: 0.00624
# Iteration: 00061 - Cloud mean cost: 0.00010 - Cloud variance: 0.00605
# Iteration: 00062 - Cloud mean cost: 0.00009 - Cloud variance: 0.00587
# Iteration: 00063 - Cloud mean cost: 0.00009 - Cloud variance: 0.00570
# Iteration: 00064 - Cloud mean cost: 0.00008 - Cloud variance: 0.00553
# Iteration: 00065 - Cloud mean cost: 0.00008 - Cloud variance: 0.00538
# Iteration: 00066 - Cloud mean cost: 0.00008 - Cloud variance: 0.00523
# Iteration: 00067 - Cloud mean cost: 0.00007 - Cloud variance: 0.00508
# Iteration: 00068 - Cloud mean cost: 0.00007 - Cloud variance: 0.00494
# Iteration: 00069 - Cloud mean cost: 0.00007 - Cloud variance: 0.00481
# Iteration: 00070 - Cloud mean cost: 0.00007 - Cloud variance: 0.00468
# Iteration: 00071 - Cloud mean cost: 0.00006 - Cloud variance: 0.00456
# Iteration: 00072 - Cloud mean cost: 0.00006 - Cloud variance: 0.00444
# Iteration: 00073 - Cloud mean cost: 0.00006 - Cloud variance: 0.00432
# Iteration: 00074 - Cloud mean cost: 0.00006 - Cloud variance: 0.00422
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-5a22a6337f82> in <module>
#      19          cost_type = "rmse", #or cross_entropy_binary
#      20          kernel_a = 0.01, alpha_init = 0, alpha_rate = 1, beta = 0, gamma = 1,
# ---> 21          verbose = True)
#
# ~\Desktop\KAUST\mlswarm\mlswarm\mlswarm.py in train(self, X, Y, method, max_epochs, n_batches, batch_size, learning_rate, cost_type, kernel_a, alpha_init, alpha_rate, beta, gamma, verbose, var_epsilon)
#      83
#      84         self.train_method = method
# ---> 85         self.cloud, self.cloud_mean, self.cloud_var, self.cost_history, self.cost_history_mean =  train_nn(X, Y, self.cloud, self.architecture, method, max_epochs, n_batches,  batch_size, learning_rate, cost_type, self.N, kernel_a, alpha_init, alpha_rate, beta, gamma, verbose, var_epsilon)
#      86
#      87     def forward_propagation(self, X, cloud):
#
# ~\Desktop\KAUST\mlswarm\mlswarm\utils.py in function_timer(*args, **kwargs)
#      13         start_cputime = time.process_time()
#      14
# ---> 15         value = func(*args, **kwargs)
#      16
#      17         end_cputime = time.process_time()
#
# ~\Desktop\KAUST\mlswarm\mlswarm\train.py in train_nn(X, Y, cloud, nn_architecture, method, max_epochs, n_batches, batch_size, learning_rate, cost_type, N, kernel_a, alpha_init, alpha_rate, beta, gamma, verbose, var_epsilon)
#      64
#      65             if method == "swarm":                        cloud, cloud_var = update_nn_weights(cloud, grads, learning_rate, N, kernel_a, alpha, beta, gamma)
# ---> 66             elif method == "swarm_derivfree":            cloud, cloud_var = update_nn_weights_derivative_free(cloud, costs, learning_rate, N, kernel_a, alpha, beta, gamma)
#      67             elif method == "gradient_descent":           cloud, cloud_var = update_nn_gd(cloud[0], grads[0], nn_architecture, learning_rate)
#      68             elif method == "swarm_nesterov":             cloud, yf, lamb, cloud_var = update_nn_weights_nesterov(cloud, yf, lamb, elapsed_iterations, grads, learning_rate, N, kernel_a, alpha, beta, gamma)
#
# ~\Desktop\KAUST\mlswarm\mlswarm\optimizers.py in update_nn_weights_derivative_free(cloud, cost, lr, N, kernel_a, alpha, beta, gamma)
#     127
#     128     #get update value to be applied on cloud
# --> 129     update, cloud_var = update_cloud_derivative_free2(cloudf, cost, lr, N, kernel_a, alpha, beta, gamma)
#     130
#     131     #use euler method
#
# ~\Desktop\KAUST\mlswarm\mlswarm\optimizers.py in update_cloud_derivative_free2(cloudf, cost, lr, N, kernel_a, alpha, beta, gamma)
#      46       cost = np.squeeze(np.array(cost)) # N vector
#      47       omega = np.divide(cloudf-cloud_mean,cloud_var) #N*N_param,N_param vector
# ---> 48       update =  ( np.einsum('j,jk -> k', kernels, np.einsum('j,jk -> jk',(cost + gamma1),omega) + gamma2*(cloudf-cloud_mean) ) +
#      49            np.einsum('j,jk -> k', cost + gamma1, gkernels) ) * float(1/N)
#      50       updates.append(update)
#
# KeyboardInterrupt:

# %%
#PLOT COST HISTORY
nn.plot_cost_history()

#ACCURACY ON TEST SET USING PARTICLE 0 WEIGHTS
nn.prediction_accuracy_particle(X_test, Y_test, acc_type = "sigmoid_accuracy", particle = 0)

#ACCURACY ON TEST SET USING CLOUD MEAN WEIGHTS
nn.prediction_accuracy_mean_particle(X_test, Y_test, acc_type = "sigmoid_accuracy")
# Out:
# Test set accuracy using particle 0: 0.80000
# Test set accuracy using cloud mean: 0.80250

# %%
import matplotlib.pyplot as plt
from mlswarm.utils import convert_prob_into_class
# %matplotlib inline 

#CLASSIFICATION VISUALIZED
Y_test_hat = nn.forward_propagation(X_test, cloud = nn.get_cloud_mean())
plt.scatter(X_test[:,0],X_test[:,1], c = convert_prob_into_class(Y_test_hat).flatten())
