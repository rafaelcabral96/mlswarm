# %%
from mlswarm.mlswarm import function
import numpy as np
np.random.seed(42)

func_list = {}
track_history = False

# %% [markdown]
# ## 1D Functions

# %%
f = lambda x: np.take(x,0,axis=0)**2
func = function(f, "Quadratic Function")

func.init_cloud([[-1],[-0.5],[0.2],[2]])

func.minimize({'algorithm':'nesterov_adaptive',
               'learning_rate':0.1})

func_list[func.name] = func
func.plot_everything(folder_name = func.name, f_dim = 1, log = True)
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.00409 (0.00000) seconds
# Cloud mean: [0.00292022]
# Function value at cloud mean: 8.527701808261124e-06
# Function value evaluated 48 times
# Best Particle at position: [0.00017338] with function value: 3.006018229449866e-08
# C:\Users\Rafael Cabral\Anaconda3\lib\site-packages\matplotlib\figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "

# %%
f = lambda x: np.take(x,0, axis = 0)**2 - (np.cos(4 * np.pi *np.take(x,0, axis = 0)) - 1)
func = function(f, "pol_and_cosine")

func.init_cloud(np.linspace(-2,1,5)[:,np.newaxis])

func.minimize({'algorithm':'nesterov_adaptive'})

func_list[func.name] = func
func.plot_everything(folder_name = func.name, f_dim = 1, log = True)
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.01688 (0.01562) seconds
# Cloud mean: [-0.00222104]
# Function value at cloud mean: 0.0003944031871197542
# Function value evaluated 185 times
# Best Particle at position: [-0.00121426] with function value: 0.00011788755565378601

# %%
f = lambda x: np.take(x,0,axis=0)**4 - 2*(np.cos(2*np.pi*np.take(x,0,axis=0)) -1) - np.take(x,0,axis=0)**2
func = function(f, "pol_and_cosine_2")

func.init_cloud(np.linspace(-2,1.5,5)[:,np.newaxis])

func.minimize({'algorithm':'nesterov_adaptive'})

func_list[func.name] = func
func.plot_everything(folder_name = func.name, f_dim = 1, log = True, limits = [-2,2])
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.01535 (0.01562) seconds
# Cloud mean: [-0.97629676]
# Function value at cloud mean: -0.02251048905273323
# Function value evaluated 170 times
# Best Particle at position: [-0.97675861] with function value: -0.02254501288462374
# C:\Users\Rafael Cabral\Anaconda3\lib\site-packages\matplotlib\ticker.py:2241: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   "Data has no positive values, and therefore cannot be "

# %%
f = lambda x: np.sin(10*np.pi*np.take(x,0,axis=0))/(2*np.take(x,0,axis=0)) + (np.take(x,0,axis=0)-1)**4
name = "Gramacy & Lee Function" 
func = function(f, name)

func.init_cloud(np.linspace(-1,1,6)[:,np.newaxis])

func.minimize({'algorithm':'nesterov_adaptive',
               'learning_rate': 0.001, 
               'var_epsilon':0.01})

func_list[func.name] = func
#func.plot_everything(folder_name = func.name, f_dim = 1, log = True, limits = [-2,2])
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.05541 (0.04688) seconds
# Cloud mean: [0.13496478]
# Function value at cloud mean: -2.739090381932025
# Function value evaluated 864 times
# Best Particle at position: [0.14264623] with function value: -2.8717432674091974

# %% [markdown]
# ## 2D Functions

# %%
f = lambda x: (1.5 - np.take(x,0,axis=0) + np.take(x,0,axis=0)*np.take(x,1,axis=0))**2 + (2.25 - np.take(x,0,axis=0) + np.take(x,0,axis=0)*np.take(x,1,axis=0)**2)**2 + (2.625 - np.take(x,0,axis=0) + np.take(x,0,axis=0)*np.take(x,1,axis=0)**3)**2
func = function(f, "Beale function")

x=np.linspace(-1, 2, 5)
y=np.linspace(-1, 2, 5)
xx,yy=np.meshgrid(x,y)
coords=np.array((xx.ravel(), yy.ravel())).T
func.init_cloud(coords)

func.minimize({'algorithm':'nesterov_adaptive',
               'var_epsilon': 0.01})

func_list[func.name] = func
#func.plot_everything(folder_name = func.name, f_dim = 2, log = True)
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.02127 (0.04688) seconds
# Cloud mean: [2.99745624 0.49606784]
# Function value at cloud mean: 0.00025006459576504313
# Function value evaluated 1000 times
# Best Particle at position: [2.97828907 0.49462482] with function value: 7.736803279446794e-05

# %%
f = lambda x: -20* np.exp(-0.2*np.sqrt(0.5*(np.take(x,0,axis=0)**2 + np.take(x,1,axis=0)**2))) - np.exp(0.5*(np.cos(2*np.pi*np.take(x,0,axis=0))+np.cos(2*np.pi*np.take(x,1,axis=0)))) + np.exp(1) + 20
func = function(f,"Ackley function")

x=np.linspace(-1, 2, 3)
y=np.linspace(-1, 2, 3)
xx,yy=np.meshgrid(x,y)
coords=np.array((xx.ravel(), yy.ravel())).T
func.init_cloud(coords)

func.minimize({'algorithm':'nesterov_adaptive'})

func_list[func.name] = func
#func.plot_everything(folder_name = func.name, f_dim = 2, log = True)
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.02061 (0.01562) seconds
# Cloud mean: [0.00020462 0.00053711]
# Function value at cloud mean: 0.0016344856113263972
# Function value evaluated 369 times
# Best Particle at position: [0.00197604 0.00058697] with function value: 0.0059435888208838605

# %%
f = lambda x: 0.5 + (np.sin(np.take(x,0,axis=0)**2 - np.take(x,1,axis=0)**2)**2 - 0.5)/(1 +0.01*(np.take(x,0,axis=0)**2 + np.take(x,1,axis=0)**2)**2)
func = function(f,"Schaffer function N. 2")

x=np.linspace(-1, 2, 3)
y=np.linspace(-1, 2, 3)
xx,yy=np.meshgrid(x,y)
coords=np.array((xx.ravel(), yy.ravel())).T
func.init_cloud(coords)

func.minimize({'algorithm':'nesterov_adaptive'})

func_list[func.name] = func
#func.plot_everything(folder_name = func.name, f_dim = 2, log = True)
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.02634 (0.04688) seconds
# Cloud mean: [-0.00042145 -0.00042145]
# Function value at cloud mean: 6.661338147750939e-16
# Function value evaluated 450 times
# Best Particle at position: [0.00011432 0.00011432] with function value: 0.0

# %%
f = lambda x: np.sin(3*np.pi*x[0])**2 + (x[0] - 1)**2 * (1 + np.sin(3*np.pi*x[1])) + (x[1]-1)**2*(1+np.sin(2*np.pi*x[1])**2)
func = function(f,"Lévi function N.13")

x=np.linspace(-1, 2, 3)
y=np.linspace(-1, 2, 3)
xx,yy=np.meshgrid(x,y)
coords=np.array((xx.ravel(), yy.ravel())).T
func.init_cloud(coords)

func.minimize({'algorithm':'nesterov_adaptive'})

func_list[func.name] = func
#func.plot_everything(folder_name = func.name, f_dim = 2, log = True)
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.01886 (0.01562) seconds
# Cloud mean: [1.00084385 1.01049544]
# Function value at cloud mean: 0.0001745242026056185
# Function value evaluated 450 times
# Best Particle at position: [1.00049747 0.99393792] with function value: 5.904629008582013e-05

# %%
f = lambda x: -0.0001*np.power(np.abs(np.sin(x[0])*np.sin(x[1])*np.exp(np.abs(100 - np.sqrt(x[0]**2 + x[1]**2)/np.pi)))+1,0.1)
func = function(f, "Cross-in-Tray Function")

x=np.linspace(-1, 2, 3)
y=np.linspace(-1, 2, 3)
xx,yy=np.meshgrid(x,y)
coords=np.array((xx.ravel(), yy.ravel())).T
func.init_cloud(coords)

func.minimize({'algorithm':'nesterov_adaptive',
               'var_epsilon':0.01})

func_list[func.name] = func
#func.plot_everything(folder_name = func.name, f_dim = 2, log = True)
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.07737 (0.07812) seconds
# Cloud mean: [1.36742329 1.3658942 ]
# Function value at cloud mean: -2.062547388710038
# Function value evaluated 1854 times
# Best Particle at position: [1.36623658 1.36623658] with function value: -2.0625506407075296

# %%
f = lambda x: -(np.sin(x[0]-x[1])**2*np.sin(x[0]+x[1])**2)/(np.sqrt(x[0]**2 + x[1]**2))
func = function(f, "Keane Function")

x=np.linspace(-1, 2, 3)
y=np.linspace(-1, 2, 3)
xx,yy=np.meshgrid(x,y)
coords=np.array((xx.ravel(), yy.ravel())).T
func.init_cloud(coords)

func.minimize({'algorithm': 'nesterov_adaptive',
               'var_epsilon': 0.01})

func_list[func.name] = func
#func.plot_everything(folder_name = func.name, f_dim = 2, log = True)
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.01864 (0.03125) seconds
# Cloud mean: [-0.02396978  1.42679335]
# Function value at cloud mean: -0.6714190348481404
# Function value evaluated 414 times
# Best Particle at position: [-0.01035139  1.41386071] with function value: -0.6729854063521228

# %%
f = lambda x: -np.cos(x[0])*np.cos(x[1])*np.exp(-(x[0]-np.pi)**2 - (x[1]-np.pi)**2)
func = function(f, "Easom Function")

x=np.linspace(-2, 6, 3)
y=np.linspace(-2, 6, 3)
xx,yy=np.meshgrid(x,y)
coords=np.array((xx.ravel(), yy.ravel())).T

func.init_cloud(coords)

func.minimize({'algorithm': 'nesterov_adaptive',
               'var_epsilon': 0.01})

func_list[func.name] = func
#func.plot_everything(folder_name = func.name, f_dim = 2, log = True,limits =[0,np.pi*2,0,np.pi*2])
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.02061 (0.01562) seconds
# Cloud mean: [3.16031844 3.16031844]
# Function value at cloud mean: -0.9989485670854865
# Function value evaluated 441 times
# Best Particle at position: [3.14374089 3.14374089] with function value: -0.999986155346044

# %% [markdown]
# # >2D Function

# %%
N_dim=2
f = lambda x: np.sum([100*(x[i+1]-x[i]**2)**2 + (1-x[i])**2 for i in range(N_dim-1)],axis=0)
func = function(f, "Rosenbrock function 3D")

#np.random.seed(42)
x=np.linspace(-1, 2, 5)
y=np.linspace(-1, 2, 5)
xx,yy=np.meshgrid(x,y)
coords=np.array((xx.ravel(), yy.ravel())).T

func.init_cloud(coords)

func.minimize({'algorithm': 'nesterov_adaptive',
               'learning_rate': 0.001,
               'var_epsilon': 0.01})

func_list[func.name] = func
#func.plot_everything(folder_name = func.name, f_dim = 2, log = True)
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.05535 (0.06250) seconds
# Cloud mean: [0.96321991 0.93926895]
# Function value at cloud mean: 0.014523438528554382
# Function value evaluated 2825 times
# Best Particle at position: [0.97766687 0.95589272] with function value: 0.0004991313125783417

# %%
N_dim=5
f = lambda x: (np.sin(x[0])**2+ np.sin(x[1])**2 - np.exp(-x[0]**2 - x[1]**2))*np.exp(-np.sin(np.sqrt(np.abs(x[0])))**2- np.sin(np.sqrt(np.abs(x[1])))**2)
func = function(f, "Xin-She Yang N. 4 Function")

np.random.seed(42)
func.init_cloud(np.array(np.random.normal(1,2,(30,N_dim))))

func.minimize({'algorithm': 'nesterov_adaptive',
               'learning_rate': 0.01,
               'var_epsilon': 0.01})

func_list[func.name] = func
#func.plot_everything(folder_name = func.name, f_dim = 5, log = True)
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.04098 (0.03125) seconds
# Cloud mean: [ 0.01472807 -0.03697734  1.62822152 -3.29197753 -2.69363139]
# Function value at cloud mean: -0.9470993159031936
# Function value evaluated 2340 times
# Best Particle at position: [-2.24261343e-03 -4.58816114e-03  1.58430119e+00 -3.31300784e+00
#  -2.68550368e+00] with function value: -0.9931493257972487

# %%
N_dim = 3
f = lambda x: np.sum([(x[i]**2 - i)**2 for i in range(N_dim)],axis=0)
func = function(f, "Qing Function")

func.init_cloud(np.array(np.random.normal(0,3,(20, N_dim))))

func.minimize({'algorithm': 'nesterov_adaptive',
               'learning_rate': 0.01,
               'var_epsilon': 0.001})

func_list[func.name] = func
#func.plot_everything(folder_name = func.name, f_dim = 3, log = True,limits =[-3,3,-3,3])
# Out:
# Convergence achieved - Particles are localized
#
# The clock time (CPU time) for f_minimize was 0.02893 (0.03125) seconds
# Cloud mean: [-0.1284792   0.99766408 -1.41179164]
# Function value at cloud mean: 0.00034109848834658736
# Function value evaluated 1160 times
# Best Particle at position: [-0.08250918  0.99783195 -1.40864558] with function value: 0.000312150556981816

# %% [markdown]
# ## Summarizing Data

# %%
import pandas as pd

# %%
data_matrix = []
for func_name, func in func_list.items():
    header, parameters = func.get_all_parameters(False, "")
    data_matrix.append(parameters)

df = pd.DataFrame(data_matrix, columns = header)
df.to_csv("Images/Benchmarking.csv", sep=',',index=False)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-840d86aca5ee> in <module>
#       1 data_matrix = []
# ----> 2 for func_name, func in func_list.items():
#       3     header, parameters = func.get_all_parameters(False, "")
#       4     data_matrix.append(parameters)
#       5
#
# NameError: name 'func_list' is not defined
